# %%
import pandas as pd

# %%
df_variance = pd.read_csv("../../data/variance_dataset.csv", index_col="CellId")

# %%
df_variance["crop_raw"].unique()

# %%
import os

# %%
file_list = os.listdir("/allen/aics/animated-cell/Saurabh/cellpack_PILR_analysis/data/sample_8d/raw_imgs_for_PILR/")

# %%
from pathlib import Path

# %%
img_folder = Path("/allen/aics/animated-cell/Saurabh/cellpack_PILR_analysis/data/sample_8d/raw_imgs_for_PILR/")

# %%
img_folder.glob("*.tiff")
# Out:
# <generator object Path.glob at 0x7f48c24bbcd0>

# %%
for file in img_folder.glob("*.tiff"):
    print(file.suffix)
# Out:
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# .tiff
# ...
