# %%
import pandas as pd
import os
from pathlib import Path

# %%
datadir = Path("/allen/aics/animated-cell/Saurabh/cellpack-analysis/data")

# %%
df_variance = pd.read_csv(datadir / "variance_dataset.csv", index_col="CellId")
# Out:
# /allen/aics/animated-cell/Saurabh/.tmp/ipykernel_14313/2989863531.py:1: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_variance = pd.read_csv(datadir / "variance_dataset.csv", index_col="CellId")

# %%
df_variance["crop_raw"].unique()
# Out:
# array(['crop_raw/7922e74b69b77d6b51ea5f1627418397ab6007105a780913663ce1344905db5c_raw.ome.tif',
#        'crop_raw/0799686d7745e67c87b3e6afe3fef49f41b1f134ed6be3ff4db45953ec89134a_raw.ome.tif',
#        'crop_raw/1690210f68126520ac086eaeda179198df8c3b232e1df62234094cdac77bae7a_raw.ome.tif',
#        ...,
#        'crop_raw/9bd2af775e7e04533e1e07e27499c71aed715b8ea460854cff6b51f65be5a844_raw.ome.tif',
#        'crop_raw/3d9e7605ceeb21a420bcd48f91113f77dd4968139c3ec07040610b604bdd6932_raw.ome.tif',
#        'crop_raw/f1c052ac29a3361811e5cd5f7476769ef62100fcf51311b7c6b489227e2c670a_raw.ome.tif'],
#       dtype=object)

# %%
img_folder = datadir / "sample_8d/raw_imgs_for_PILR/"

# %%
img_folder.glob("*.tiff")
# Out:
# <generator object Path.glob at 0x7f7f0fbc8900>
